# %%
from ipywidgets import interact
import numpy as np
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6564666c-83db-4080-b22d-91266dafa6e1">Loading BokehJS ...</span>
#     </div>

# %%
Length = 1.0
x = np.linspace(0, Length, 200)
y = np.sqrt(2/Length) * np.sin(1 * np.pi * x/Length)
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(n=1):
 #   r.data_source.data['x'] =  np.linspace(0, Length, 200)
    r.data_source.data['y'] = np.sqrt(2/Length) * np.sin(n * np.pi * x/Length)
    push_notebook()

# %%
interact(update, n=(1,10))
# Out:
# interactive(children=(IntSlider(value=1, description=u'n', max=10, min=1), Output()), _dom_classes=('widget-interact',))
# <function __main__.update>

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a132808d-ebe5-4ced-a200-435d577dff11"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a132808d-ebe5-4ced-a200-435d577dff11").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f7a44359-d289-4f6e-a087-bb7ba2da2bc1", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a132808d-ebe5-4ced-a200-435d577dff11");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a132808d-ebe5-4ced-a200-435d577dff11' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1a5349df-edb6-4892-b65f-c34680b9d642":{"roots":{"references":[{"attributes":{},"id":"07c220a3-f404-4925-accd-857259f99ba1","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"e11f4c95-1078-4c5c-922f-b700657e6f6f","type":"LinearAxis"}],"left":[{"id":"c25ce232-b738-4073-a6e1-bae95d3043fd","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"e11f4c95-1078-4c5c-922f-b700657e6f6f","type":"LinearAxis"},{"id":"5d1cde08-f818-4bed-ab52-48ce8f5901bc","type":"Grid"},{"id":"c25ce232-b738-4073-a6e1-bae95d3043fd","type":"LinearAxis"},{"id":"bff7b50a-2db3-4919-be9b-4067a689c929","type":"Grid"},{"id":"bcd44062-074a-480b-b7ea-bb21334764cc","type":"BoxAnnotation"},{"id":"c587a79c-e04f-4a83-b0a3-ccbe206fd63a","type":"GlyphRenderer"}],"title":{"id":"4401b50f-c042-4fd4-8981-0f2583b60a6a","type":"Title"},"tool_events":{"id":"33b9d687-7c4b-4841-9009-47bfc98e0d77","type":"ToolEvents"},"toolbar":{"id":"193c711a-ac3d-4f64-abc4-9ec6447ec481","type":"Toolbar"},"x_range":{"id":"90db6ee1-b169-4526-a1b1-ab17ab434b48","type":"DataRange1d"},"y_range":{"id":"7c7b236c-95d8-49e2-a09c-6e7729e42a77","type":"Range1d"}},"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"14ad7a7b-c429-43d0-bd5e-ae1357dca74c","type":"Line"},{"attributes":{"plot":null,"text":"simple line example"},"id":"4401b50f-c042-4fd4-8981-0f2583b60a6a","type":"Title"},{"attributes":{},"id":"b625e098-7e60-4afb-8134-fa69f601c13f","type":"BasicTicker"},{"attributes":{"overlay":{"id":"bcd44062-074a-480b-b7ea-bb21334764cc","type":"BoxAnnotation"},"plot":{"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","subtype":"Figure","type":"Plot"}},"id":"ba4dd7ec-5888-4687-a2ae-6be54a7e839a","type":"BoxZoomTool"},{"attributes":{},"id":"33b9d687-7c4b-4841-9009-47bfc98e0d77","type":"ToolEvents"},{"attributes":{"plot":{"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","subtype":"Figure","type":"Plot"}},"id":"b9ae3fa8-78a8-4aad-be52-dd79116e77d2","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"89cc9c73-3cdf-4c7e-9763-f06f74c2b61c","type":"Line"},{"attributes":{"formatter":{"id":"33546eca-aeac-4300-9290-2efa5a862fb7","type":"BasicTickFormatter"},"plot":{"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e07d34-8bd1-48ea-8064-ebeed6b3d7db","type":"BasicTicker"}},"id":"c25ce232-b738-4073-a6e1-bae95d3043fd","type":"LinearAxis"},{"attributes":{"callback":null},"id":"90db6ee1-b169-4526-a1b1-ab17ab434b48","type":"DataRange1d"},{"attributes":{},"id":"33546eca-aeac-4300-9290-2efa5a862fb7","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"fd6d84e3-d613-4ff4-b0ec-ce92e1fc719f","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"77f88a10-7f20-4e3c-b20d-02a69dd85e3f","type":"PanTool"},{"id":"c8a00a8a-590e-4a31-8bf7-505a9feb1384","type":"WheelZoomTool"},{"id":"ba4dd7ec-5888-4687-a2ae-6be54a7e839a","type":"BoxZoomTool"},{"id":"d07ac538-baf5-4efb-b2cc-309815fc06c5","type":"SaveTool"},{"id":"b9ae3fa8-78a8-4aad-be52-dd79116e77d2","type":"ResetTool"},{"id":"fbb5bac0-ecda-4c66-bb5c-4710242d20ce","type":"HelpTool"}]},"id":"193c711a-ac3d-4f64-abc4-9ec6447ec481","type":"Toolbar"},{"attributes":{},"id":"02e07d34-8bd1-48ea-8064-ebeed6b3d7db","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e07d34-8bd1-48ea-8064-ebeed6b3d7db","type":"BasicTicker"}},"id":"bff7b50a-2db3-4919-be9b-4067a689c929","type":"Grid"},{"attributes":{"plot":{"id":"683e5fa3-4e2b-4fb0-9a0e-f47be691e1ec","sub ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>
