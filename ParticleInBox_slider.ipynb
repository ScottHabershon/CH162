# %%
from ipywidgets import interact
import numpy as np
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dfc933ea-b508-4c8a-8eb7-441efa19aef8">Loading BokehJS ...</span>
#     </div>

# %%
Length = 1.0
x = np.linspace(0, Length, 200)
y = np.sqrt(2/Length) * np.sin(1 * np.pi * x/Length)
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(n=1):
 #   r.data_source.data['x'] =  np.linspace(0, Length, 200)
    r.data_source.data['y'] = np.sqrt(2/Length) * np.sin(n * np.pi * x/Length)
    push_notebook()

# %%
interact(update, n=(1,10));
# Out:
# interactive(children=(IntSlider(value=1, description=u'n', max=10, min=1), Output()), _dom_classes=('widget-interact',))

# %%
show(p, notebook_handle=True);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2e38ade-9282-4079-a4ec-0fbad32b2257"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f2e38ade-9282-4079-a4ec-0fbad32b2257").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("43c7cbe3-6b7e-47b1-a068-a15c8ba6fdf8", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2e38ade-9282-4079-a4ec-0fbad32b2257");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2e38ade-9282-4079-a4ec-0fbad32b2257' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"10355f28-8546-4ffe-87aa-4fe9fab73793":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"e4915527-83ea-4c96-b3bc-e2c57bfcc03c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"}},"id":"8e8e71b4-0550-491a-b923-819233aaf20d","type":"PanTool"},{"attributes":{"plot":{"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"}},"id":"694219d4-8646-4939-8ccd-d724be5d42d1","type":"ResetTool"},{"attributes":{"plot":null,"text":"simple line example"},"id":"1d7bc8b1-e75a-4b3d-bb4d-51100621c16f","type":"Title"},{"attributes":{"callback":null,"end":5,"start":-5},"id":"4143cc46-9261-4523-9705-0aba2424a4ec","type":"Range1d"},{"attributes":{"below":[{"id":"495831c5-410f-419f-82fc-2b3cabae1434","type":"LinearAxis"}],"left":[{"id":"53b8ac1d-cd4f-4696-9ee8-409f5ca0a912","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"495831c5-410f-419f-82fc-2b3cabae1434","type":"LinearAxis"},{"id":"f65e0bf7-e6bc-4fba-a600-097a5a578b56","type":"Grid"},{"id":"53b8ac1d-cd4f-4696-9ee8-409f5ca0a912","type":"LinearAxis"},{"id":"549eeec9-398a-456d-b421-4a60441b937a","type":"Grid"},{"id":"156a3565-d481-43d3-8d37-d9e0ca2c96a9","type":"BoxAnnotation"},{"id":"9114ecc0-acef-47df-ba2a-a47b1a7af90e","type":"GlyphRenderer"}],"title":{"id":"1d7bc8b1-e75a-4b3d-bb4d-51100621c16f","type":"Title"},"tool_events":{"id":"524084f4-490d-4e40-a528-3b75b5636ca1","type":"ToolEvents"},"toolbar":{"id":"aa940644-4729-449b-a716-fafdd45f4c1b","type":"Toolbar"},"x_range":{"id":"029ba442-1f9b-4577-a85b-b8af07b98c6b","type":"DataRange1d"},"y_range":{"id":"4143cc46-9261-4523-9705-0aba2424a4ec","type":"Range1d"}},"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"be4ba791-f29a-49e9-9939-b2c780b46c6d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"e13a6ae1-d687-4daa-a927-4c3d7604780e","type":"BasicTickFormatter"},"plot":{"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a80b7c1-5e11-48fc-b78e-a1632fd23b25","type":"BasicTicker"}},"id":"53b8ac1d-cd4f-4696-9ee8-409f5ca0a912","type":"LinearAxis"},{"attributes":{},"id":"5a80b7c1-5e11-48fc-b78e-a1632fd23b25","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8e8e71b4-0550-491a-b923-819233aaf20d","type":"PanTool"},{"id":"149b0d07-9379-4444-9ff5-7c20e5cd2347","type":"WheelZoomTool"},{"id":"55ba29d6-1ad3-474a-9dc4-3a53f5369dc8","type":"BoxZoomTool"},{"id":"9d635183-6842-4f78-a09d-91869f3e510a","type":"SaveTool"},{"id":"694219d4-8646-4939-8ccd-d724be5d42d1","type":"ResetTool"},{"id":"469cd02f-9e2e-4381-b389-f741266502e0","type":"HelpTool"}]},"id":"aa940644-4729-449b-a716-fafdd45f4c1b","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a80b7c1-5e11-48fc-b78e-a1632fd23b25","type":"BasicTicker"}},"id":"549eeec9-398a-456d-b421-4a60441b937a","type":"Grid"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"427e9ea1-dd21-47a1-ace2-a07870fc1b88","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"156a3565-d481-43d3-8d37-d9e0ca2c96a9","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"1b0124bb-56dc-4c9a-9c0e-b36a03ed672f","subtype":"Figure","type":"Plot"}},"id":"149b0d07-9379-4444-9ff5-7c20e5cd2347","type":"WheelZoomTool"},{"attributes":{},"id":"9879104f-4 ...
